# %% [markdown]
# ## Imports

# %%
from Pose_Functions import *
import matplotlib.pyplot as plt
import mediapipe as mp

# %%
video_path = "../EnisProject/data/test_squat.mp4"
model_path = "data/pose_landmarker.task"
save_path = "data/test_nodes.json"

data_to_json(video_path, save_path, model_path)
# Out:
# I0000 00:00:1775386620.058262 10373391 gl_context.cc:407] GL version: 2.1 (2.1 Metal - 90.5), renderer: Apple M4
# W0000 00:00:1775386620.126497 10373396 inference_feedback_manager.cc:121] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1775386620.133275 10373398 inference_feedback_manager.cc:121] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
