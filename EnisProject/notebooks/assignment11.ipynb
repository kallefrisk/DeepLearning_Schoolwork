# %%
import os
import random
import copy
import numpy as np
import mlflow
import torch
import glob 
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import json
from datetime import datetime
from sklearn.metrics import (
    accuracy_score, f1_score, precision_score, recall_score,
    classification_report, confusion_matrix, ConfusionMatrixDisplay,
    roc_auc_score, RocCurveDisplay
)


if torch.backends.mps.is_available():
    device = torch.device("mps")      # Mac GPU (Apple Silicon)
elif torch.cuda.is_available():
    device = torch.device("cuda")     # Nvidia GPU
else:
    device = torch.device("cpu")

# device = torch.device("cpu")  # Force CPU for testing time
random_seed = 42


mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("Running_or_not")
mlflow.enable_system_metrics_logging()

# %%
def add_frame_overlap_column(full_csv_path, trimmed_csv_path, column_name="running_video"):
    df_full = pd.read_csv(full_csv_path)
    df_trimmed = pd.read_csv(trimmed_csv_path)

    trimmed_frames = set(df_trimmed["FrameNo"].values)

    values = []

    for frame in df_full["FrameNo"]:
        if frame in trimmed_frames:
            values.append(1)
        else:
            values.append(0)

    df_full[column_name] = values


    return df_full

# %% [markdown]
# ### Added column for kinect

# %%
import os

# Paths
full_dir = "../../MainProject/Assignment11/data/kinect_good_preprocessed_not_cut"
trimmed_dir = "../../MainProject/Assignment9/data/kinect_good_preprocessed"
output_dir = "../../MainProject/Assignment11/data/kinect_good_preprocessed_not_cut_start_stop"


for file_name in os.listdir(full_dir):
    if file_name.endswith(".csv"):

        full_path = os.path.join(full_dir, file_name)
        trimmed_path = os.path.join(trimmed_dir, file_name)

        if not os.path.exists(trimmed_path):
            print(f"Skipping (no match): {file_name}")
            continue

        df = add_frame_overlap_column(full_path, trimmed_path)

        output_path = os.path.join(output_dir, file_name)
        df.to_csv(output_path, index=False)

        print(f"Saved: {file_name}")
# Out:
# Saved: A100_kinect.csv
# Saved: A11_kinect.csv
# Saved: A26_kinect.csv
# Saved: A137_kinect.csv
# Saved: A73_kinect.csv
# Saved: B9_kinect.csv
# Saved: A155_kinect.csv
# Saved: A44_kinect.csv
# Saved: A90_kinect.csv
# Saved: A149_kinect.csv
# Saved: A58_kinect.csv
# Saved: B4_kinect.csv
# Saved: A158_kinect.csv
# Saved: A3_kinect.csv
# Saved: A49_kinect.csv
# Saved: B17_kinect.csv
# Saved: B20_kinect.csv
# Saved: A81_kinect.csv
# Saved: A144_kinect.csv
# Saved: A55_kinect.csv
# Saved: A62_kinect.csv
# Saved: A37_kinect.csv
# Saved: A126_kinect.csv
# Saved: A111_kinect.csv
# Saved: A84_kinect.csv
# Saved: B12_kinect.csv
# Saved: A6_kinect.csv
# Saved: B1_kinect.csv
# Saved: A108_kinect.csv
# Saved: A19_kinect.csv
# Saved: A98_kinect.csv
# Saved: A67_kinect.csv
# Saved: A141_kinect.csv
# Saved: A50_kinect.csv
# Saved: A114_kinect.csv
# Saved: A32_kinect.csv
# Saved: A123_kinect.csv
# Saved: A23_kinect.csv
# Saved: A132_kinect.csv
# Saved: A105_kinect.csv
# Saved: A14_kinect.csv
# Saved: A150_kinect.csv
# Saved: A41_kinect.csv
# Saved: A76_kinect.csv
# Saved: A89_kinect.csv
# Saved: A119_kinect.csv
# Saved: A95_kinect.csv
# Saved: A92_kinect.csv
# Saved: A129_kinect.csv
# Saved: A38_kinect.csv
# Saved: A135_kinect.csv
# Saved: A24_kinect.csv
# Saved: A13_kinect.csv
# Saved: A102_kinect.csv
# Saved: A46_kinect.csv
# Saved: A157_kinect.csv
# Saved: A71_kinect.csv
# Saved: B18_kinect.csv
# Skipping (no match): A60_kinect.csv
# Saved: A57_kinect.csv
# Saved: A146_kinect.csv
# Saved: A113_kinect.csv
# Saved: A124_kinect.csv
# Saved: A35_kinect.csv
# Saved: A1_kinect.csv
# Saved: B6_kinect.csv
# Saved: B22_kinect.csv
# Saved: B15_kinect.csv
# Saved: A138_kinect.csv
# Saved: A29_kinect.csv
# Saved: A83_kinect.csv
# Saved: A52_kinect.csv
# Saved: A143_kinect.csv
# Saved: A65_kinect.csv
# Saved: A121_kinect.csv
# Saved: A30_kinect.csv
# Saved: A116_kinect.csv
# Saved: A86_kinect.csv
# Saved: B10_kinect.csv
# Saved: A79_kinect.csv
# Saved: B3_kinect.csv
# Saved: A4_kinect.csv
# Saved: A68_kinect.csv
# Saved: A97_kinect.csv
# Saved: A16_kinect.csv
# Saved: A130_kinect.csv
# Saved: A21_kinect.csv
# Saved: A74_kinect.csv
# Saved: A9_kinect.csv
# Saved: A43_kinect.csv
# Saved: A152_kinect.csv
# Saved: B13_kinect.csv
# Saved: A7_kinect.csv
# Saved: A18_kinect.csv
# Saved: A109_kinect.csv
# Saved: A85_kinect.csv
# Saved: A66_kinect.csv
# Saved: A51_kinect.csv
# Saved: A140_kinect.csv
# Saved: A115_kinect.csv
# Saved: A122_kinect.csv
# Saved: A33_kinect.csv
# Saved: A99_kinect.csv
# Saved: A88_kinect.csv
# Saved: A133_kinect.csv
# Saved: A22_kinect.csv
# Saved: A15_kinect.csv
# Saved: A104_kinect.csv
# Saved: A40_kinect.csv
# Saved: A151_kinect.csv
# Saved: A77_kinect.csv
# Saved: A94_kinect.csv
# Saved: A118_kinect.csv
# Saved: A10_kinect.csv
# Saved: A101_kinect.csv
# Saved: A136_kinect.csv
# Saved: A27_kinect.csv
# Saved: B8_kinect.csv
# Saved: A72_kinect.csv
# Saved: A45_kinect.csv
# Saved: A154_kinect.csv
# Saved: A59_kinect.csv
# Saved: A148_kinect.csv
# Saved: A91_kinect.csv
# Saved: A80_kinect.csv
# Saved: B5_kinect.csv
# Saved: A48_kinect.csv
# Saved: A2_kinect.csv
# Saved: A159_kinect.csv
# Saved: B16_kinect.csv
# Saved: B21_kinect.csv
# Saved: A54_kinect.csv
# Saved: A145_kinect.csv
# Saved: A63_kinect.csv
# Saved: A127_kinect.csv
# Saved: A36_kinect.csv
# Saved: A110_kinect.csv
# Saved: A142_kinect.csv
# Saved: A53_kinect.csv
# Saved: A64_kinect.csv
# Saved: A31_kinect.csv
# Saved: A120_kinect.csv
# Saved: A117_kinect.csv
# Saved: B11_kinect.csv
# Saved: B2_kinect.csv
# Saved: A78_kinect.csv
# Saved: A5_kinect.csv
# Saved: A87_kinect.csv
# Saved: A96_kinect.csv
# Saved: A69_kinect.csv
# Saved: A106_kinect.csv
# Saved: A17_kinect.csv
# Saved: A20_kinect.csv
# Saved: A131_kinect.csv
# Saved: A75_kinect.csv
# Saved: A153_kinect.csv
# Saved: A42_kinect.csv
# Saved: A8_kinect.csv
# Saved: A39_kinect.csv
# Saved: A128_kinect.csv
# Saved: A93_kinect.csv
# Saved: A25_kinect.csv
# Saved: A134_kinect.csv
# Saved: A103_kinect.csv
# Saved: A12_kinect.csv
# Saved: A156_kinect.csv
# Saved: A47_kinect.csv
# Saved: A70_kinect.csv
# Saved: B19_kinect.csv
# Saved: A61_kinect.csv
# Saved: A147_kinect.csv
# Saved: A56_kinect.csv
# Saved: A112_kinect.csv
# Saved: A34_kinect.csv
# Saved: A125_kinect.csv
# Saved: A82_kinect.csv
# Saved: B7_kinect.csv
# Saved: B14_kinect.csv
# Saved: A28_kinect.csv
# Saved: A139_kinect.csv

# %% [markdown]
# ## Add column for mediapipe

# %%
# Paths
full_dir = "../../MainProject/Assignment10/data/csv_of_all_videos"
trimmed_dir = "../../MainProject/Assignment9/data/kinect_good_preprocessed"
output_dir = "../../MainProject/Assignment11/data/mediapipe_not_cut_start_stop"



for mp_file in os.listdir(full_dir):

    if mp_file.endswith("_mediapipe.csv"):

        base_id = mp_file.replace("_mediapipe.csv", "")
        kinect_file = f"{base_id}_kinect.csv"
        mp_full_path = os.path.join(full_dir, mp_file)
        kinect_cut_path = os.path.join(trimmed_dir, kinect_file)

        if not os.path.exists(kinect_cut_path):
            print(f"Skipping (no match): {mp_file}")
            continue


        df = add_frame_overlap_column(
            full_csv_path=mp_full_path,
            trimmed_csv_path=kinect_cut_path,

            column_name="running_video"

        )


        output_path = os.path.join(output_dir, mp_file)
        df.to_csv(output_path, index=False)

        print(f"Saved: {mp_file}")
# Out:
# Saved: A75_mediapipe.csv
# Saved: A121_mediapipe.csv
# Saved: A136_mediapipe.csv
# Saved: A62_mediapipe.csv
# Saved: A118_mediapipe.csv
# Saved: A66_mediapipe.csv
# Saved: A132_mediapipe.csv
# Saved: A125_mediapipe.csv
# Saved: A71_mediapipe.csv
# Saved: A48_mediapipe.csv
# Saved: A12_mediapipe.csv
# Saved: A146_mediapipe.csv
# Saved: A151_mediapipe.csv
# Saved: B3_mediapipe.csv
# Saved: A96_mediapipe.csv
# Saved: A81_mediapipe.csv
# Saved: A155_mediapipe.csv
# Saved: A142_mediapipe.csv
# Saved: A16_mediapipe.csv
# Saved: A85_mediapipe.csv
# Saved: A38_mediapipe.csv
# Saved: A92_mediapipe.csv
# Saved: B7_mediapipe.csv
# Saved: A152_mediapipe.csv
# Saved: A145_mediapipe.csv
# Saved: A11_mediapipe.csv
# Saved: A9_mediapipe.csv
# Saved: A82_mediapipe.csv
# Saved: A28_mediapipe.csv
# Saved: A95_mediapipe.csv
# Saved: A15_mediapipe.csv
# Saved: A141_mediapipe.csv
# Saved: B19_mediapipe.csv
# Saved: A156_mediapipe.csv
# Saved: B4_mediapipe.csv
# Saved: A91_mediapipe.csv
# Saved: B20_mediapipe.csv
# Saved: A86_mediapipe.csv
# Saved: A61_mediapipe.csv
# Saved: A135_mediapipe.csv
# Saved: A122_mediapipe.csv
# Saved: A76_mediapipe.csv
# Saved: A58_mediapipe.csv
# Saved: A72_mediapipe.csv
# Saved: A126_mediapipe.csv
# Saved: A131_mediapipe.csv
# Saved: A65_mediapipe.csv
# Saved: A108_mediapipe.csv
# Saved: A78_mediapipe.csv
# Saved: A102_mediapipe.csv
# Saved: A56_mediapipe.csv
# Saved: A41_mediapipe.csv
# Saved: A115_mediapipe.csv
# Saved: A128_mediapipe.csv
# Saved: A111_mediapipe.csv
# Saved: A45_mediapipe.csv
# Saved: A52_mediapipe.csv
# Saved: A106_mediapipe.csv
# Saved: B13_mediapipe.csv
# Saved: A7_mediapipe.csv
# Saved: A31_mediapipe.csv
# Saved: A26_mediapipe.csv
# Saved: A3_mediapipe.csv
# Saved: B17_mediapipe.csv
# Saved: A158_mediapipe.csv
# Saved: A22_mediapipe.csv
# Saved: A35_mediapipe.csv
# Saved: A88_mediapipe.csv
# Saved: A4_mediapipe.csv
# Saved: B10_mediapipe.csv
# Saved: A148_mediapipe.csv
# Saved: A98_mediapipe.csv
# Saved: A25_mediapipe.csv
# Saved: A32_mediapipe.csv
# Saved: B14_mediapipe.csv
# Saved: A18_mediapipe.csv
# Saved: A36_mediapipe.csv
# Saved: A21_mediapipe.csv
# Saved: B9_mediapipe.csv
# Saved: A138_mediapipe.csv
# Saved: A116_mediapipe.csv
# Saved: A42_mediapipe.csv
# Saved: A55_mediapipe.csv
# Saved: A101_mediapipe.csv
# Saved: A68_mediapipe.csv
# Saved: A105_mediapipe.csv
# Saved: A51_mediapipe.csv
# Saved: A46_mediapipe.csv
# Saved: A112_mediapipe.csv
# Saved: A20_mediapipe.csv
# Saved: B8_mediapipe.csv
# Saved: A37_mediapipe.csv
# Saved: A19_mediapipe.csv
# Saved: B15_mediapipe.csv
# Saved: A1_mediapipe.csv
# Saved: A33_mediapipe.csv
# Saved: A24_mediapipe.csv
# Saved: A99_mediapipe.csv
# Saved: A5_mediapipe.csv
# Saved: B11_mediapipe.csv
# Saved: A149_mediapipe.csv
# Saved: A113_mediapipe.csv
# Saved: A47_mediapipe.csv
# Saved: A50_mediapipe.csv
# Saved: A104_mediapipe.csv
# Saved: A69_mediapipe.csv
# Saved: A100_mediapipe.csv
# Saved: A54_mediapipe.csv
# Saved: A43_mediapipe.csv
# Saved: A117_mediapipe.csv
# Saved: A139_mediapipe.csv
# Saved: A53_mediapipe.csv
# Saved: A44_mediapipe.csv
# Saved: A110_mediapipe.csv
# Saved: A129_mediapipe.csv
# Saved: A114_mediapipe.csv
# Saved: A40_mediapipe.csv
# Saved: A57_mediapipe.csv
# Saved: A103_mediapipe.csv
# Saved: A79_mediapipe.csv
# Saved: A89_mediapipe.csv
# Saved: A34_mediapipe.csv
# Saved: A23_mediapipe.csv
# Saved: A159_mediapipe.csv
# Saved: A2_mediapipe.csv
# Saved: B16_mediapipe.csv
# Saved: A27_mediapipe.csv
# Saved: A30_mediapipe.csv
# Saved: B12_mediapipe.csv
# Saved: A6_mediapipe.csv
# Saved: A87_mediapipe.csv
# Saved: B5_mediapipe.csv
# Saved: A90_mediapipe.csv
# Saved: B21_mediapipe.csv
# Saved: A157_mediapipe.csv
# Saved: A140_mediapipe.csv
# Saved: B18_mediapipe.csv
# Saved: A14_mediapipe.csv
# Saved: A94_mediapipe.csv
# Saved: A29_mediapipe.csv
# Saved: B1_mediapipe.csv
# Saved: A83_mediapipe.csv
# Saved: A10_mediapipe.csv
# Saved: A144_mediapipe.csv
# Saved: A8_mediapipe.csv
# Saved: A153_mediapipe.csv
# Saved: A109_mediapipe.csv
# Saved: A64_mediapipe.csv
# Saved: A130_mediapipe.csv
# Saved: A127_mediapipe.csv
# Saved: A73_mediapipe.csv
# Saved: A59_mediapipe.csv
# Saved: A77_mediapipe.csv
# Saved: A123_mediapipe.csv
# Saved: A134_mediapipe.csv
# Skipping (no match): A60_mediapipe.csv
# Saved: A49_mediapipe.csv
# Saved: A70_mediapipe.csv
# Saved: A124_mediapipe.csv
# Saved: A133_mediapipe.csv
# Saved: A67_mediapipe.csv
# Saved: A119_mediapipe.csv
# Saved: A63_mediapipe.csv
# Saved: A137_mediapipe.csv
# Saved: A120_mediapipe.csv
# Saved: A74_mediapipe.csv
# Saved: A93_mediapipe.csv
# Saved: B22_mediapipe.csv
# Saved: B6_mediapipe.csv
# Saved: A39_mediapipe.csv
# Saved: A84_mediapipe.csv
# Saved: A17_mediapipe.csv
# Saved: A143_mediapipe.csv
# Saved: A154_mediapipe.csv
# Saved: A80_mediapipe.csv
# Saved: B2_mediapipe.csv
# Saved: A97_mediapipe.csv
# Saved: A150_mediapipe.csv
# Saved: A147_mediapipe.csv
# Saved: A13_mediapipe.csv

# %% [markdown]
# ### Functions to manege data

# %%
def input_target_split(dataframe):
    input_cols = []
    for c in dataframe.columns:
        if c.endswith("_x") or c.endswith("_y") or c.endswith("_z"):
            input_cols.append(c)

    input_data = dataframe[input_cols]
    target_data = dataframe[["running_video"]]  # Binary label: 1 frame per timestep
    return input_data, target_data


def split_data_by_video(datafolder, seq_length=30, stride=30,
                        train_ratio=0.7, val_ratio=0.15, random_seed=42):
    """
    Split by VIDEO FILE to prevent ANY data leakage between train/val/test.

    Returns:
        train_x, train_y, val_x, val_y, test_x, test_y
        X shape: (n_sequences, seq_length, 39)   -- all x/y/z coords
        y shape: (n_sequences, seq_length, 1)    -- binary running_video label
    """


    csv_files = glob.glob(os.path.join(datafolder, "*.csv"))
    print(f"Found {len(csv_files)} video files")

    random.seed(random_seed)
    random.shuffle(csv_files)

    n_files = len(csv_files)
    n_train = int(n_files * train_ratio)
    n_val = int(n_files * val_ratio)

    train_files = csv_files[:n_train]
    val_files   = csv_files[n_train:n_train + n_val]
    test_files  = csv_files[n_train + n_val:]

    print(f"Train videos: {len(train_files)}, Val videos: {len(val_files)}, Test videos: {len(test_files)}")

    def extract_sequences(file_list):
        all_X, all_y = [], []
        for file_path in file_list:
            df = pd.read_csv(file_path)
            X_df, y_df = input_target_split(df)
            X_np = X_df.values.astype(np.float32)
            y_np = y_df.values.astype(np.float32)  # shape: (n_frames, 1)
            n_frames = len(df)
            for i in range(0, n_frames - seq_length + 1, stride):
                all_X.append(torch.tensor(X_np[i:i + seq_length]))
                all_y.append(torch.tensor(y_np[i:i + seq_length]))
        if not all_X:
            n_features = 39  # 13 joints x 3 coords
            return torch.empty(0, seq_length, n_features), torch.empty(0, seq_length, 1)
        return torch.stack(all_X), torch.stack(all_y)

    train_x, train_y = extract_sequences(train_files)
    val_x,   val_y   = extract_sequences(val_files)
    test_x,  test_y  = extract_sequences(test_files)

    print(f"\nTrain sequences: {len(train_x)}, Val: {len(val_x)}, Test: {len(test_x)}")
    print(f"X shape: {train_x.shape}, y shape: {train_y.shape}")

    return train_x, train_y, val_x, val_y, test_x, test_y

# %%
def mirror_sequences_tensor(X, Y):
    """
    Mirror sequences left-right.
    X: (n_sequences, seq_length, 39) -- x/y/z coords
    Y: (n_sequences, seq_length, 1)  -- binary label (unchanged by mirroring)
    """
    mirror_pairs = [
        (1, 3),   # shoulders
        (2, 4),   # elbows
        (5, 6),   # hands
        (7, 8),   # hips
        (9, 10),  # knees
        (11, 12), # feet
    ]

    X_mirrored = X.clone()

    for left, right in mirror_pairs:
        # x coords
        lx, rx = 3 * left, 3 * right
        X_mirrored[:, :, lx], X_mirrored[:, :, rx] = \
            -X_mirrored[:, :, rx].clone(), -X_mirrored[:, :, lx].clone()
        # y coords
        ly, ry = 3 * left + 1, 3 * right + 1
        X_mirrored[:, :, ly], X_mirrored[:, :, ry] = \
            X_mirrored[:, :, ry].clone(), X_mirrored[:, :, ly].clone()
        # z coords
        lz, rz = 3 * left + 2, 3 * right + 2
        X_mirrored[:, :, lz], X_mirrored[:, :, rz] = \
            X_mirrored[:, :, rz].clone(), X_mirrored[:, :, lz].clone()

    return X_mirrored, Y  # Label is unchanged by mirroring


def add_noise_to_sequences_tensor(X, Y, noise_std=0.002, prob=0.5, seed=None):
    """
    Add Gaussian noise to pose coordinates.
    X: (n_sequences, seq_length, 39)
    Y: (n_sequences, seq_length, 1)  -- binary label (unchanged)
    """
    if seed is not None:
        torch.manual_seed(seed)

    X_noisy = X.clone()
    mask = torch.rand(len(X)) < prob

    if mask.any():
        n_noisy = mask.sum().item()
        noise = torch.randn(n_noisy, X.shape[1], X.shape[2]) * noise_std
        X_noisy[mask] = X_noisy[mask] + noise

    return X_noisy, Y  # Label is unchanged by noise

# %% [markdown]
# ### Functions for model manegement

# %%
def load_champion_info(metadata_dir):
    info_path = os.path.join(metadata_dir, "champion_info.json")

    if not os.path.exists(info_path):
        return None

    try:
        with open(info_path, "r") as f:
            return json.load(f)
    except:
        return None


def save_champion_model(model, model_name, f1, params, champion_dir, metadata_dir):
    os.makedirs(champion_dir, exist_ok=True)
    os.makedirs(metadata_dir, exist_ok=True)

    model_path = os.path.join(champion_dir, "champion_model.pt")
    info_path = os.path.join(metadata_dir, "champion_info.json")

    torch.save(model.state_dict(), model_path)

    info = {
        "model_name": model_name,
        "model_path": model_path,
        "f1": float(f1),
        "saved_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "params": params
    }

    with open(info_path, "w") as f:
        json.dump(info, f, indent=2)

    print(f"Champion model saved with F1: {f1:.4f}")


def update_champion(model, model_name, f1, params, champion_dir, metadata_dir):
    current = load_champion_info(metadata_dir)

    if current is None:
        print("No champion yet → saving first model")
        save_champion_model(model, model_name, f1, params, champion_dir, metadata_dir)

    elif f1 > current["f1"]:
        print(f"New champion! {f1:.4f} > {current['f1']:.4f}")
        save_champion_model(model, model_name, f1, params, champion_dir, metadata_dir)

    else:
        print(f"Model not better ({f1:.4f} ≤ {current['f1']:.4f})")

# %% [markdown]
# ### Functions for modelling

# %%
class MovementClassifier(nn.Module):
    """
    Sequence-to-sequence binary classifier.
    Input:  (batch, seq_len, 39)  -- 13 joints x 3 coords
    Output: (batch, seq_len, 1)   -- logit per frame (use BCEWithLogitsLoss)
    """
    def __init__(self, hidden_layers: list, layer_type="LSTM", dropout=0.0):
        super().__init__()
        self.layer_type = layer_type

        input_size = 39  # 13 joints x 3 (x, y, z)
        rnn_class = nn.LSTM if layer_type == "LSTM" else nn.GRU

        self.rnns  = nn.ModuleList()
        self.drops = nn.ModuleList()

        sizes = [input_size] + hidden_layers
        for i in range(len(hidden_layers)):
            self.rnns.append(rnn_class(sizes[i], sizes[i + 1], batch_first=True))
            self.drops.append(nn.Dropout(dropout) if dropout > 0 else nn.Identity())

        self.fc_out = nn.Linear(hidden_layers[-1], 1)  # 1 logit per frame

    def forward(self, x):
        for rnn, drop in zip(self.rnns, self.drops):
            x, _ = rnn(x)
            x = drop(x)
        return self.fc_out(x)  # (batch, seq_len, 1)

# %% [markdown]
# ### Parameters

# %%
params = {
    "hidden_layers": [256, 128, 128, 64, 64],
    "layer_type": "LSTM",
    "dropout": 0.4,
    "learning_rate": 0.0005,
    "batch_size": 64,
    "epochs": 500,
    "seq_length": 30,
    "stride": 15,
    "weight_decay": 1e-5,
    "run_name": "regulised_movement_classifier_lstm",
    # "patience": 10
}

model = MovementClassifier(
    hidden_layers=params["hidden_layers"],
    layer_type=params["layer_type"],
    dropout=params["dropout"]
).to(device)

loss_fn = nn.BCEWithLogitsLoss()  # Binary cross-entropy (includes sigmoid internally)
optimizer = optim.Adam(model.parameters(), lr=params["learning_rate"], weight_decay=params["weight_decay"])

datafolder = "../../MainProject/Assignment11/data/mediapipe_not_cut_start_stop"
train_x, train_y, val_x, val_y, test_x, test_y = split_data_by_video(
    datafolder,
    seq_length=params["seq_length"],
    stride=params["stride"]
)

print(f"Train: {len(train_x)}, Val: {len(val_x)}, Test: {len(test_x)}")

train_x, train_y = train_x.to(device), train_y.to(device)
val_x,   val_y   = val_x.to(device),   val_y.to(device)
test_x,  test_y  = test_x.to(device),  test_y.to(device)
# Out:
# Found 179 video files
# Train videos: 125, Val videos: 26, Test videos: 28
#
# Train sequences: 1630, Val: 312, Test: 335
# X shape: torch.Size([1630, 30, 39]), y shape: torch.Size([1630, 30, 1])
# Train: 1630, Val: 312, Test: 335

# %% [markdown]
# ### Training models

# %%
def compute_classification_metrics(logits, targets):
    """Convert logits -> binary preds and compute accuracy, F1, precision, recall."""
    probs  = torch.sigmoid(logits).cpu().numpy().flatten()
    preds  = (probs > 0.5).astype(int)
    labels = targets.cpu().numpy().flatten().astype(int)
    return {
        "accuracy":  accuracy_score(labels, preds),
        "f1":        f1_score(labels, preds, zero_division=0),
        "precision": precision_score(labels, preds, zero_division=0),
        "recall":    recall_score(labels, preds, zero_division=0),
        "probs":     probs,
        "preds":     preds,
        "labels":    labels,
    }


champion_dir = "../assignment11_models/champion"
metadata_dir = "../assignment11_models/metadata"
best_val_f1 = 0
best_state = None
epochs_no_improve = 0

with mlflow.start_run(run_name=params["run_name"]) as run:
    mlflow.log_params(params)

    train_dataset = TensorDataset(train_x, train_y)
    val_dataset   = TensorDataset(val_x,   val_y)
    test_dataset  = TensorDataset(test_x,  test_y)

    train_loader = DataLoader(train_dataset, batch_size=params["batch_size"], shuffle=True)
    val_loader   = DataLoader(val_dataset,   batch_size=params["batch_size"], shuffle=False)
    test_loader  = DataLoader(test_dataset,  batch_size=params["batch_size"], shuffle=False)

    best_val_loss = float("inf")
    epochs_no_improve = 0

    for epoch in range(params["epochs"]):

        # ── Training ─────────────────────────────────────────────────────────
        model.train()
        train_losses = []
        all_train_logits, all_train_labels = [], []

        for batch_x, batch_y in train_loader:
            optimizer.zero_grad()
            logits = model(batch_x)          # (batch, seq_len, 1)
            loss   = loss_fn(logits, batch_y)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())
            all_train_logits.append(logits.detach())
            all_train_labels.append(batch_y)

        avg_train_loss = np.mean(train_losses)
        train_logits_cat = torch.cat(all_train_logits)
        train_labels_cat = torch.cat(all_train_labels)
        train_m = compute_classification_metrics(train_logits_cat, train_labels_cat)

        # ── Validation ───────────────────────────────────────────────────────
        model.eval()
        val_losses = []
        all_val_logits, all_val_labels = [], []

        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                logits = model(batch_x)
                val_losses.append(loss_fn(logits, batch_y).item())
                all_val_logits.append(logits)
                all_val_labels.append(batch_y)

        avg_val_loss = np.mean(val_losses)
        val_logits_cat = torch.cat(all_val_logits)
        val_labels_cat = torch.cat(all_val_labels)
        val_m = compute_classification_metrics(val_logits_cat, val_labels_cat)

        if val_m["f1"] > best_val_f1:
            best_val_f1 = val_m["f1"]
            best_state = copy.deepcopy(model.state_dict())
            epochs_no_improve = 0

            update_champion(
                model=model,
                model_name=params["run_name"],
                f1=best_val_f1,
                params=params,
                champion_dir=champion_dir,
                metadata_dir=metadata_dir)
            
            mlflow.pytorch.log_model(model, artifact_path="best_model")
        else:
            epochs_no_improve += 1

        mlflow.log_metrics({
            "train_loss":      avg_train_loss,
            "train_accuracy":  train_m["accuracy"],
            "train_f1":        train_m["f1"],
            "train_precision": train_m["precision"],
            "train_recall":    train_m["recall"],
            "val_loss":        avg_val_loss,
            "val_accuracy":    val_m["accuracy"],
            "val_f1":          val_m["f1"],
            "val_precision":   val_m["precision"],
            "val_recall":      val_m["recall"],
        }, step=epoch)

        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1}/{params['epochs']} "
                f"| train_loss: {avg_train_loss:.4f}  train_f1: {train_m['f1']:.4f} "
                f"| val_loss: {avg_val_loss:.4f}  val_f1: {val_m['f1']:.4f}  "
                f"val_acc: {val_m['accuracy']:.4f}")

        """
        # Early stopping (uncomment patience in params to enable)
        if params.get("patience"):
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                epochs_no_improve = 0
                mlflow.pytorch.log_model(model, artifact_path="best_model")
            else:
                epochs_no_improve += 1
            if epochs_no_improve >= params["patience"]:
                print(f"Early stopping at epoch {epoch+1}")
                break
        """


    # ── Test evaluation ───────────────────────────────────────────────────────
    model.eval()
    test_losses = []
    all_test_logits, all_test_labels = [], []

    with torch.no_grad():
        for batch_x, batch_y in test_loader:
            logits = model(batch_x)
            test_losses.append(loss_fn(logits, batch_y).item())
            all_test_logits.append(logits)
            all_test_labels.append(batch_y)

    avg_test_loss  = np.mean(test_losses)
    test_logits_cat = torch.cat(all_test_logits)
    test_labels_cat = torch.cat(all_test_labels)
    test_m = compute_classification_metrics(test_logits_cat, test_labels_cat)

    # ROC-AUC (needs probability scores, not binary preds)
    test_auc = roc_auc_score(test_m["labels"], test_m["probs"])

    mlflow.log_metrics({
        "test_loss":      avg_test_loss,
        "test_accuracy":  test_m["accuracy"],
        "test_f1":        test_m["f1"],
        "test_precision": test_m["precision"],
        "test_recall":    test_m["recall"],
        "test_auc":       test_auc,
    })

    print(f"\n✅ Test Results:")
    print(classification_report(test_m["labels"], test_m["preds"],
                                target_names=["Not movement", "Movement"]))

    # ── Confusion matrix ──────────────────────────────────────────────────────
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    cm = confusion_matrix(test_m["labels"], test_m["preds"])
    ConfusionMatrixDisplay(cm, display_labels=["Not movement", "Movement"]).plot(
        ax=axes[0], colorbar=False
    )
    axes[0].set_title("Confusion Matrix (Test set)")

    # ── ROC curve ─────────────────────────────────────────────────────────────
    RocCurveDisplay.from_predictions(
        test_m["labels"], test_m["probs"],
        name=f"GRU (AUC={test_auc:.3f})",
        ax=axes[1]
    )
    axes[1].set_title("ROC Curve (Test set)")

    plt.tight_layout()
    plt.savefig("test_evaluation.png", dpi=150)
    plt.show()

    # ── Temporal prediction plot (first test video sequence) ──────────────────
    first_seq_true  = test_m["labels"][:params["seq_length"]]
    first_seq_probs = test_m["probs"][:params["seq_length"]]
    first_seq_pred  = test_m["preds"][:params["seq_length"]]

    fig2, ax = plt.subplots(figsize=(12, 3))
    ax.plot(first_seq_true,  label="True label",       linewidth=2)
    ax.plot(first_seq_probs, label="Predicted prob",   linewidth=2, linestyle="--")
    ax.plot(first_seq_pred,  label="Predicted (0.5)",  linewidth=1, linestyle=":")
    ax.set_xlabel("Frame")
    ax.set_ylabel("Movement label")
    ax.set_title("Frame-level predictions over time (first test sequence)")
    ax.legend()
    ax.set_ylim(-0.1, 1.1)
    plt.tight_layout()
    plt.savefig("temporal_predictions.png", dpi=150)
    mlflow.log_artifact("temporal_predictions.png")
    plt.show()

    mlflow.pytorch.log_model(model, artifact_path=f"final_model_{params['run_name']}")
    print(f"\nAUC: {test_auc:.4f}  |  F1: {test_m['f1']:.4f}  |  Accuracy: {test_m['accuracy']:.4f}")
# Out:
# 2026/04/27 21:53:14 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2026/04/27 21:53:14 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2026/04/27 21:53:15 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/04/27 21:53:15 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is to set `serialization_format` to 'pt2' to save the PyTorch model using the safe graph model format.
# Model not better (0.9212 ≤ 0.9289)
# 2026/04/27 21:53:21 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/04/27 21:53:22 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is to set `serialization_format` to 'pt2' to save the PyTorch model using the safe graph model format.
# Model not better (0.9282 ≤ 0.9289)
# Epoch 10/500 | train_loss: 0.0419  train_f1: 0.9862 | val_loss: 0.6415  val_f1: 0.9151  val_acc: 0.8851
# Epoch 20/500 | train_loss: 0.0410  train_f1: 0.9865 | val_loss: 0.6093  val_f1: 0.9218  val_acc: 0.8935
# Epoch 30/500 | train_loss: 0.0410  train_f1: 0.9862 | val_loss: 0.6786  val_f1: 0.9125  val_acc: 0.8821
# Epoch 40/500 | train_loss: 0.0475  train_f1: 0.9850 | val_loss: 0.6315  val_f1: 0.9148  val_acc: 0.8846
# Epoch 50/500 | train_loss: 0.0424  train_f1: 0.9864 | val_loss: 0.5591  val_f1: 0.9173  val_acc: 0.8875
# Epoch 60/500 | train_loss: 0.0505  train_f1: 0.9853 | val_loss: 0.5620  val_f1: 0.9159  val_acc: 0.8862
# 2026/04/27 21:54:05 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Model not better (0.9289 ≤ 0.9289)
# 2026/04/27 21:54:06 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is to set `serialization_format` to 'pt2' to save the PyTorch model using the safe graph model format.
# Epoch 70/500 | train_loss: 0.0394  train_f1: 0.9869 | val_loss: 0.6290  val_f1: 0.9172  val_acc: 0.8873
# Epoch 80/500 | train_loss: 0.0394  train_f1: 0.9870 | val_loss: 0.6606  val_f1: 0.9176  val_acc: 0.8878
# Epoch 90/500 | train_loss: 0.0471  train_f1: 0.9845 | val_loss: 0.6718  val_f1: 0.9128  val_acc: 0.8818
# Epoch 100/500 | train_loss: 0.0427  train_f1: 0.9863 | val_loss: 0.5679  val_f1: 0.9170  val_acc: 0.8880
# Epoch 110/500 | train_loss: 0.0446  train_f1: 0.9858 | val_loss: 0.6572  val_f1: 0.9136  val_acc: 0.8830
# Epoch 120/500 | train_loss: 0.0634  train_f1: 0.9810 | val_loss: 0.4853  val_f1: 0.9179  val_acc: 0.8878
# Epoch 130/500 | train_loss: 0.0414  train_f1: 0.9864 | val_loss: 0.5781  val_f1: 0.9210  val_acc: 0.8926
# Epoch 140/500 | train_loss: 0.0391  train_f1: 0.9875 | val_loss: 0.6053  val_f1: 0.9230  val_acc: 0.8953
# Epoch 150/500 | train_loss: 0.0413  train_f1: 0.9862 | val_loss: 0.6780  val_f1: 0.9183  val_acc: 0.8891
# Epoch 160/500 | train_loss: 0.0375  train_f1: 0.9879 | val_loss: 0.6900  val_f1: 0.9158  val_acc: 0.8853
# Epoch 170/500 | train_loss: 0.0371  train_f1: 0.9876 | val_loss: 0.6384  val_f1: 0.9200  val_acc: 0.8912
# Epoch 180/500 | train_loss: 0.0667  train_f1: 0.9801 | val_loss: 0.4161  val_f1: 0.9257  val_acc: 0.8986
# Epoch 190/500 | train_loss: 0.0491  train_f1: 0.9847 | val_loss: 0.5761  val_f1: 0.9114  val_acc: 0.8797
# Epoch 200/500 | train_loss: 0.0394  train_f1: 0.9872 | val_loss: 0.5741  val_f1: 0.9214  val_acc: 0.8931
# Epoch 210/500 | train_loss: 0.0379  train_f1: 0.9877 | val_loss: 0.6198  val_f1: 0.9213  val_acc: 0.8927
# Epoch 220/500 | train_loss: 0.0419  train_f1: 0.9863 | val_loss: 0.6042  val_f1: 0.9249  val_acc: 0.8971
# Epoch 230/500 | train_loss: 0.0752  train_f1: 0.9783 | val_loss: 0.5967  val_f1: 0.9122  val_acc: 0.8815
# Epoch 240/500 | train_loss: 0.0390  train_f1: 0.9874 | val_loss: 0.6220  val_f1: 0.9207  val_acc: 0.8921
# Epoch 250/500 | train_loss: 0.0378  train_f1: 0.9873 | val_loss: 0.6937  val_f1: 0.9186  val_acc: 0.8895
# Epoch 260/500 | train_loss: 0.0384  train_f1: 0.9881 | val_loss: 0.6227  val_f1: 0.9204  val_acc: 0.8910
# 2026/04/27 21:56:32 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# New champion! 0.9296 > 0.9289
# Champion model saved with F1: 0.9296
# 2026/04/27 21:56:32 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is to set `serialization_format` to 'pt2' to save the PyTorch model using the safe graph model format.
# Epoch 270/500 | train_loss: 0.0455  train_f1: 0.9853 | val_loss: 0.5610  val_f1: 0.9296  val_acc: 0.9032
# Epoch 280/500 | train_loss: 0.0360  train_f1: 0.9882 | val_loss: 0.6715  val_f1: 0.9240  val_acc: 0.8956
# Epoch 290/500 | train_loss: 0.0450  train_f1: 0.9855 | val_loss: 0.4965  val_f1: 0.9228  val_acc: 0.8948
# Epoch 300/500 | train_loss: 0.0408  train_f1: 0.9866 | val_loss: 0.5459  val_f1: 0.9227  val_acc: 0.8942
# Epoch 310/500 | train_loss: 0.0422  train_f1: 0.9864 | val_loss: 0.5026  val_f1: 0.9251  val_acc: 0.8972
# Epoch 320/500 | train_loss: 0.0400  train_f1: 0.9874 | val_loss: 0.5788  val_f1: 0.9246  val_acc: 0.8967
# Epoch 330/500 | train_loss: 0.0356  train_f1: 0.9885 | val_loss: 0.6376  val_f1: 0.9253  val_acc: 0.8981
# Epoch 340/500 | train_loss: 0.0400  train_f1: 0.9874 | val_loss: 0.5069  val_f1: 0.9259  val_acc: 0.8989
# Epoch 350/500 | train_loss: 0.0375  train_f1: 0.9883 | val_loss: 0.6691  val_f1: 0.9216  val_acc: 0.8931
# Epoch 360/500 | train_loss: 0.0470  train_f1: 0.9853 | val_loss: 0.5479  val_f1: 0.9247  val_acc: 0.8966
# Epoch 370/500 | train_loss: 0.0696  train_f1: 0.9795 | val_loss: 0.4415  val_f1: 0.9195  val_acc: 0.8903
# Epoch 380/500 | train_loss: 0.0375  train_f1: 0.9879 | val_loss: 0.6319  val_f1: 0.9208  val_acc: 0.8919
# Epoch 390/500 | train_loss: 0.1179  train_f1: 0.9645 | val_loss: 0.3327  val_f1: 0.9253  val_acc: 0.8966
# Epoch 400/500 | train_loss: 0.0353  train_f1: 0.9884 | val_loss: 0.7300  val_f1: 0.9143  val_acc: 0.8842
# Epoch 410/500 | train_loss: 0.0369  train_f1: 0.9882 | val_loss: 0.7546  val_f1: 0.9118  val_acc: 0.8803
# Epoch 420/500 | train_loss: 0.0922  train_f1: 0.9734 | val_loss: 0.4021  val_f1: 0.9163  val_acc: 0.8860
# Epoch 430/500 | train_loss: 0.0352  train_f1: 0.9888 | val_loss: 0.5911  val_f1: 0.9259  val_acc: 0.8982
# Epoch 440/500 | train_loss: 0.0372  train_f1: 0.9879 | val_loss: 0.5572  val_f1: 0.9245  val_acc: 0.8969
# Epoch 450/500 | train_loss: 0.0339  train_f1: 0.9886 | val_loss: 0.6981  val_f1: 0.9189  val_acc: 0.8901
# Epoch 460/500 | train_loss: 0.0371  train_f1: 0.9876 | val_loss: 0.6259  val_f1: 0.9184  val_acc: 0.8885
# Epoch 470/500 | train_loss: 0.0390  train_f1: 0.9873 | val_loss: 0.5309  val_f1: 0.9229  val_acc: 0.8949
# Epoch 480/500 | train_loss: 0.0347  train_f1: 0.9887 | val_loss: 0.6986  val_f1: 0.9188  val_acc: 0.8892
# Epoch 490/500 | train_loss: 0.0335  train_f1: 0.9887 | val_loss: 0.7623  val_f1: 0.9172  val_acc: 0.8880
# Epoch 500/500 | train_loss: 0.0404  train_f1: 0.9874 | val_loss: 0.6973  val_f1: 0.9197  val_acc: 0.8908
#
# ✅ Test Results:
#               precision    recall  f1-score   support
#
# Not movement       0.85      0.74      0.79      2780
#     Movement       0.91      0.95      0.93      7270
#
#     accuracy                           0.89     10050
#    macro avg       0.88      0.85      0.86     10050
# weighted avg       0.89      0.89      0.89     10050
# 2026/04/27 21:59:10 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/04/27 21:59:11 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is to set `serialization_format` to 'pt2' to save the PyTorch model using the safe graph model format.
# 2026/04/27 21:59:16 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2026/04/27 21:59:17 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# AUC: 0.9492  |  F1: 0.9273  |  Accuracy: 0.8922
# 🏃 View run regulised_movement_classifier_lstm at: http://127.0.0.1:5000/#/experiments/386488090859353142/runs/400aefcdced3453f857b18eedbbedaca
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/386488090859353142
